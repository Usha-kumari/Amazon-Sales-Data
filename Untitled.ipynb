# %%
 import pandas as pd
 import numpy as np
 import matplotlib.pyplot as plt
 # %matplotlib inline
 import seaborn as sns
 import warnings
 warnings.filterwarnings('ignore')

# %%
sales= pd.read_csv("Amazon Sale Report.csv")
sales.head(20)
# Out:
#     index             Order ID      Date                        Status  \
# 0       0  405-8078784-5731545  04-30-22                     Cancelled
# 1       1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2       2  404-0687676-7273146  04-30-22                       Shipped
# 3       3  403-9615377-8133951  04-30-22                     Cancelled
# 4       4  407-1069790-7240320  04-30-22                       Shipped
# 5       5  404-1490984-4578765  04-30-22                       Shipped
# 6       6  408-5748499-6859555  04-30-22                       Shipped
# 7       7  406-7807733-3785945  04-30-22  Shipped - Delivered to Buyer
# 8       8  407-5443024-5233168  04-30-22                     Cancelled
# 9       9  402-4393761-0311520  04-30-22                       Shipped
# 10     10  407-5633625-6970741  04-30-22                       Shipped
# 11     11  171-4638481-6326716  04-30-22                       Shipped
# ...

# %%
sales.tail()
# Out:
#          index             Order ID      Date   Status Fulfilment  \
# 128971  128970  406-6001380-7673107  05-31-22  Shipped     Amazon
# 128972  128971  402-9551604-7544318  05-31-22  Shipped     Amazon
# 128973  128972  407-9547469-3152358  05-31-22  Shipped     Amazon
# 128974  128973  402-6184140-0545956  05-31-22  Shipped     Amazon
# 128975  128974  408-7436540-8728312  05-31-22  Shipped     Amazon
#
#        Sales Channel ship-service-level Category Size Courier Status  ...  \
# 128971     Amazon.in          Expedited    Shirt   XL        Shipped  ...
# 128972     Amazon.in          Expedited  T-shirt    M        Shipped  ...
# 128973     Amazon.in          Expedited  Blazzer  XXL        Shipped  ...
# 128974     Amazon.in          Expedited  T-shirt   XS        Shipped  ...
# 128975     Amazon.in          Expedited  T-shirt    S        Shipped  ...
#
#         currency  Amount  ship-city    ship-state ship-postal-code  \
# ...

# %%
 #Checking the shape
 sales.shape
# Out:
# (128976, 21)

# %%
sales.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by', 'New', 'PendingS'],
#       dtype='object')

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 21 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128976 non-null  int64
#  1   Order ID            128976 non-null  object
#  2   Date                128976 non-null  object
#  3   Status              128976 non-null  object
#  4   Fulfilment          128976 non-null  object
#  5   Sales Channel       128976 non-null  object
#  6   ship-service-level  128976 non-null  object
#  7   Category            128976 non-null  object
#  8   Size                128976 non-null  object
#  9   Courier Status      128976 non-null  object
#  10  Qty                 128976 non-null  int64
#  11  currency            121176 non-null  object
#  12  Amount              121176 non-null  float64
#  13  ship-city           128941 non-null  object
#  14  ship-state          128941 non-null  object
# ...

# %%
sales.isnull().sum()
# Out:
# index                      0
# Order ID                   0
# Date                       0
# Status                     0
# Fulfilment                 0
# Sales Channel              0
# ship-service-level         0
# Category                   0
# Size                       0
# Courier Status             0
# Qty                        0
# currency                7800
# Amount                  7800
# ship-city                 35
# ship-state                35
# ship-postal-code          35
# ship-country              35
# B2B                        0
# fulfilled-by           89713
# New                   128976
# PendingS              128976
# dtype: int64

# %%
 sales.describe()
# Out:
#                index            Qty         Amount  ship-postal-code  New  \
# count  128976.000000  128976.000000  121176.000000     128941.000000  0.0
# mean    64486.130427       0.904401     648.562176     463945.677744  NaN
# std     37232.897832       0.313368     281.185041     191458.488954  NaN
# min         0.000000       0.000000       0.000000     110001.000000  NaN
# 25%     32242.750000       1.000000     449.000000     382421.000000  NaN
# 50%     64486.500000       1.000000     605.000000     500033.000000  NaN
# 75%     96730.250000       1.000000     788.000000     600024.000000  NaN
# max    128974.000000      15.000000    5584.000000     989898.000000  NaN
#
#        PendingS
# count       0.0
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
 sales['Category'].unique()
# Out:
# array(['T-shirt', 'Shirt', 'Blazzer', 'Trousers', 'Perfume', 'Socks',
#        'Shoes', 'Wallet', 'Watch'], dtype=object)

# %%
 sales['Order Year'] = pd.DatetimeIndex(sales['Date']).year
 sales['Order Quarter']= pd.DatetimeIndex(sales['Date']).quarter
 sales['Order Month']= pd.DatetimeIndex(sales['Date']).month

# %%
 sales1= sales[['index', 'Order ID','Date', 'Order Year', 'Order Quarter', 'Order Month', 'Status', 'Fulfilment', 'Sales Channel',
       'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
       'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
       'ship-country', 'B2B', 'fulfilled-by', 'New', 'PendingS']]

# %%
sales1
# Out:
#          index             Order ID      Date  Order Year  Order Quarter  \
# 0            0  405-8078784-5731545  04-30-22        2022              2
# 1            1  171-9198151-1101146  04-30-22        2022              2
# 2            2  404-0687676-7273146  04-30-22        2022              2
# 3            3  403-9615377-8133951  04-30-22        2022              2
# 4            4  407-1069790-7240320  04-30-22        2022              2
# ...        ...                  ...       ...         ...            ...
# 128971  128970  406-6001380-7673107  05-31-22        2022              2
# 128972  128971  402-9551604-7544318  05-31-22        2022              2
# 128973  128972  407-9547469-3152358  05-31-22        2022              2
# 128974  128973  402-6184140-0545956  05-31-22        2022              2
# 128975  128974  408-7436540-8728312  05-31-22        2022              2
#
#         Order Month                        Status Fulfilment Sales Channel  \
# ...

# %%
sort_sales1 =sales1.sort_values(by=['Qty'], ascending= False)

# %%
Items_sold = sort_sales1[['ship-city','ship-state', 'Category', 'Order Year', 'Order Quarter','Order Month', 'Qty']]

# %%
Items_sold
# Out:
#                                                 ship-city       ship-state  \
# 938                                                 Surat          Gujarat
# 3637                                                Surat          Gujarat
# 3632                                                Surat          Gujarat
# 42040                                              GUNTUR   ANDHRA PRADESH
# 113351                                            ALIGARH    UTTAR PRADESH
# ...                                                   ...              ...
# 40339                                             ramgarh  JAMMU & KASHMIR
# 71759   147/19 B Keshab Chandra Sen Street Kolkata nin...      WEST BENGAL
# 26223                                            DAHIVADI      MAHARASHTRA
# 51859                                                PUNE      MAHARASHTRA
# 0                                                  MUMBAI      MAHARASHTRA
#
#         Category  Order Year  Order Quarter  Order Month  Qty
# ...

# %%
 Items_sold.tail()
# Out:
#                                                ship-city       ship-state  \
# 40339                                            ramgarh  JAMMU & KASHMIR
# 71759  147/19 B Keshab Chandra Sen Street Kolkata nin...      WEST BENGAL
# 26223                                           DAHIVADI      MAHARASHTRA
# 51859                                               PUNE      MAHARASHTRA
# 0                                                 MUMBAI      MAHARASHTRA
#
#        Category  Order Year  Order Quarter  Order Month  Qty
# 40339   T-shirt        2022              2            4    0
# 71759     Shirt        2022              2            5    0
# 26223  Trousers        2022              2            4    0
# 51859  Trousers        2022              2            5    0
# 0       T-shirt        2022              2            4    0

# %%
sort_sales2 =sales1.sort_values(by=['Amount'], ascending= False)

# %%
Items_revenue = sort_sales2[['ship-city','ship-state', 'Category', 'Order Year', 'Order Quarter','Order Month', 'Qty']]

# %%
 Items_revenue.head()
# Out:
#         ship-city      ship-state Category  Order Year  Order Quarter  \
# 42040      GUNTUR  ANDHRA PRADESH  T-shirt        2022              2
# 11161   JALANDHAR          PUNJAB  T-shirt        2022              2
# 24495      Jaipur       RAJASTHAN  T-shirt        2022              2
# 89151     LUCKNOW   UTTAR PRADESH  T-shirt        2022              2
# 121226     MUMBAI     MAHARASHTRA  T-shirt        2022              2
#
#         Order Month  Qty
# 42040             4    8
# 11161             4    5
# 24495             4    0
# 89151             5    4
# 121226            6    2

# %%
 Items_revenue.tail()
# Out:
#             ship-city      ship-state Category  Order Year  Order Quarter  \
# 128904      ANANTAPUR  ANDHRA PRADESH    Shirt        2022              2
# 128908  GREATER NOIDA   UTTAR PRADESH  T-shirt        2022              2
# 128909  GREATER NOIDA   UTTAR PRADESH  T-shirt        2022              2
# 128959      Bengaluru       KARNATAKA  T-shirt        2022              2
# 128968        Kolkata     WEST BENGAL    Shirt        2022              2
#
#         Order Month  Qty
# 128904            5    0
# 128908            5    0
# 128909            5    0
# 128959            5    0
# 128968            5    0

# %%
 Year_wise = sales1.sort_values(by=['Order Month'])

# %%
Year_2022 =Year_wise[(Year_wise['Order Year'] == 2022)]

# %%
Year_2022
# Out:
#          index             Order ID      Date  Order Year  Order Quarter  \
# 48964    48963  402-2922177-1493131  03-31-22        2022              1
# 48990    48989  407-2352301-8497951  03-31-22        2022              1
# 48991    48990  407-7115918-3595555  03-31-22        2022              1
# 48992    48991  402-6785096-8802758  03-31-22        2022              1
# 48993    48992  407-6819253-3672316  03-31-22        2022              1
# ...        ...                  ...       ...         ...            ...
# 103784  103783  171-2707398-0064339  06-18-22        2022              2
# 103785  103784  404-5161860-8234707  06-18-22        2022              2
# 103786  103785  404-5133644-6997965  06-18-22        2022              2
# 103770  103769  403-6335664-5856323  06-18-22        2022              2
# 99570    99569  405-2951045-8874758  06-22-22        2022              2
#
#         Order Month                        Status Fulfilment Sales Channel  \
# ...

# %%
sales.dtypes
# Out:
# index                   int64
# Order ID               object
# Date                   object
# Status                 object
# Fulfilment             object
# Sales Channel          object
# ship-service-level     object
# Category               object
# Size                   object
# Courier Status         object
# Qty                     int64
# currency               object
# Amount                float64
# ship-city              object
# ship-state             object
# ship-postal-code      float64
# ship-country           object
# B2B                      bool
# fulfilled-by           object
# New                   float64
# PendingS              float64
# Order Year              int32
# Order Quarter           int32
# Order Month             int32
# dtype: object

# %%
sales.columns.isnull()
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False])

# %%
np.max(sales['Amount'])
# Out:
# 5584.0

# %%
np.min(sales['Amount'])
# Out:
# 0.0

# %%
plt.hist(sales['Amount'])
# Out:
# (array([5.1980e+04, 6.0046e+04, 8.9810e+03, 1.3200e+02, 2.9000e+01,
#         5.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 2.0000e+00]),
#  array([   0. ,  558.4, 1116.8, 1675.2, 2233.6, 2792. , 3350.4, 3908.8,
#         4467.2, 5025.6, 5584. ]),
#  <BarContainer object of 10 artists>)

# %%
 plt.scatter(sales['Amount'],sales['Qty'])

# %%
ax = sns.countplot(x = 'Category',data = sales)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = sales.groupby(['ship-state'], as_index=False)['Qty'].sum().sort_values(by='Qty', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'ship-state',y= 'Qty')
# Out:
# <Axes: xlabel='ship-state', ylabel='Qty'>

# %%
Customer1 = sales.groupby(['Category'], as_index=False)['Qty'].sum().sort_values(by='Category', ascending=False, hue = 'Segment').head(10)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = Customer1, x = 'Category',y= 'Qty')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 Customer1 = sales.groupby(['Category'], as_index=False)['Qty'].sum().sort_values(by='Category', ascending=False, hue = 'Segment').head(10)
#       3 sns.set(rc={'figure.figsize':(15,5)})
#       4 sns.barplot(data = Customer1, x = 'Category',y= 'Qty')
#
# TypeError: DataFrame.sort_values() got an unexpected keyword argument 'hue'
